# %%
from matplotlib.pyplot import figure
from sklearn.metrics import f1_score
from scipy.sparse import csr_matrix
from numpy import count_nonzero
import matplotlib.pyplot as plt
from numpy import linalg as LA
import collections, numpy
from numpy import array
from time import time
import seaborn as sns
import pandas as pd
import numpy as np
import scipy.io
import datetime
import random
import math

# %%
mushrooms = scipy.io.loadmat('C:\\Users\\Hunor\\Documents\\Moj Master rad\\Podaci za testiranje NKNKJTO\\ADULT9.mat')
train = pd.DataFrame(mushrooms['Xtrain'].toarray())

test = pd.DataFrame(mushrooms['Xtest'].toarray()) 

#labels = pd.DataFrame(mushrooms['ztrain'].toarray())
labels = pd.DataFrame(mushrooms['ztrain'])
labels = labels[0]
#labels = np.array(labels[0])

#labels_test = pd.DataFrame(mushrooms['ztest'].toarray())
labels_test = pd.DataFrame(mushrooms['ztest'])
labels_test = labels_test[0]
#labels_test = np.array(labels_test[0])

np.random.seed(11)
x0 = np.random.uniform(0,1,train.shape[1])

# %%
def aimh(N_k):
    return (N_max-N_k)/N_max

# %%
#def hinge_loss(x, N): RADILO SA OVIM 100% SAMO SPORO
#    total = 0
#    for i in range(N):
#        product = np.matmul(x,train.iloc[i,:])
#        total += max(0,1-labels[i]*product)
#    return l/2*LA.norm(x,2)**2+total/N

# %%
def hinge_loss(x,N):
    prediction = train.iloc[:N,:].dot(x)
    maximums = np.maximum(0,1-labels[:N]*prediction)
    return l/2*LA.norm(x)**2+1/N*maximums.sum()

# %%
#def hl_der(x, N): #RADILO SA OVIM 100% SAMO SPORO
#    sum1 = np.zeros(train.shape[1])
#    sum2 = np.zeros(train.shape[1])
#    for i in range(N):
#        check = 1-labels[i]*np.matmul(x, train.iloc[i,:])
#        labels_train = labels[i]*train.iloc[i,:]
#        if check > 0:
#            sum1 += labels_train
#        if check == 0:
#            sum2 += np.random.uniform(0,1)*labels_train
#    return np.array(l*x - sum1/N - sum2/N)

# %%
def hl_der(x,N):
    y=train.iloc[:N,:].dot(x)*labels[:N]
    maximumi= 1-y
    izvodi_svi = (train.iloc[:N,:].T*labels[:N]).T
    izvodi_veci = izvodi_svi[maximumi>0]
    izvodi_nula = izvodi_svi[maximumi==0]
    beta=np.random.uniform(0,1,np.size(izvodi_nula))
    if len(izvodi_nula)!=0:
        return np.array(l*x-izvodi_veci.sum()/N-np.dot(izvodi_nula,beta)/N)
    elif len(izvodi_nula)==0:
        return np.array(l*x-(izvodi_veci.sum())/N)

# %%
def new_sample(N_k): #working
    return math.ceil(N_max*(1-r*aimh(N_k)))

# %%
def merit_function(x_k, N_k, theta_k):
    return theta_k*hinge_loss(x_k, N_k)+(1-theta_k)*aimh(N_k)

# %%
def find_theta(x, N_tilda, N, theta):
    sum1 = merit_function(x, N_tilda, theta)-merit_function(x, N, theta)
    sum2 = (1-r)/2*(aimh(N_tilda)-aimh(N))
    if sum1 <= sum2:
        #print("Theta - Same")
        return theta
    else:
        sum3 = (1+r)*(aimh(N)-aimh(N_tilda))
        sum4 = hinge_loss(x, N_tilda)-hinge_loss(x, N)+aimh(N)-aimh(N_tilda)
        #print("Theta - Upgrade")
        return sum3/(2*sum4)

# %%
def model_Y(x, p, N, B):
    return np.matmul(np.matmul(p,np.linalg.inv(B)),p)/2 + sup_gp(x, p, N)

# %%
def sup_gp(x, p, N):
    sum1 = 0
    sum2 = 0
    for i in range(N):
        check = 1-labels[i]*np.matmul(train.iloc[i,:],x)
        if check == 0:
            inf = labels[i]*np.matmul(train.iloc[i,:],p)
            if inf < 0:
                sum1 += inf
        if check > 0:
            sum2 += labels[i]*train.iloc[i,:]
    return np.matmul(l*x - (sum2/N),p) - sum1/N

# %%
def argsup_gp(x, p, N): #working
    sum1 = np.zeros(x.shape)
    sum2 = np.zeros(x.shape)
    for i in range(N):
        check = 1-labels[i]*np.matmul(train.iloc[i,:],x) 
        if check > 0:
            sum1 += labels[i]*train.iloc[i][:]
        if check == 0:
            if labels[i]*np.matul(train.iloc[i,:],p) < 0:
                sum2 += lables[i]*train.iloc[i][:]           
    return np.array(l*x-sum1/N-sum2/N)

# %%
def descentDirection(g0_tilda, e, i_max, B, x, N): #working
    G_tilda = []
    G_bar = []
    P = []
    E = []
    
    #Step 0
    g0_bar = g0_tilda
    G_bar.append(g0_bar)
    G_tilda.append(g0_tilda)
    P.append(np.matmul(-B, G_tilda[0]))
    
    #Step 1
    G_tilda.append(argsup_gp(x, P[0], N))
        
    #Step 2
    E.append(np.matmul(P[0],G_tilda[1])-np.matmul(P[0],G_bar[0]))
    
    #Step 3
    i = 0
    while (np.matmul(G_tilda[i+1],P[i])>0 or E[0]>e) and E[i]>0 and i<i_max:
        first = np.matmul(G_bar[i]-G_tilda[i+1],np.matmul(B,G_bar[i]))
        second = np.matmul(G_bar[i]-G_tilda[i+1],np.matmul(B,G_bar[i]-G_tilda[i+1]))
        ni = min(1,first/second)
        G_bar.append((1-ni)*G_bar[i]+ni*G_tilda[i+1])
        P.append((1-ni)*P[i]-ni*np.matmul(B,G_tilda[i+1]))
        G_tilda.append(argsup_gp(x, P[i+1], N))
        e_list = []
        j = 0
        while j <= i+1:
            sum1 = np.matmul(P[j],G_tilda[j+1])
            sum2 = np.matmul(P[j],G_bar[j])+np.matmul(P[i+1],G_bar[i+1])
            e_list.append(sum1-sum2/2)
            j += 1
        E.append(min(e_list))
        i += 1
        
    #Step 4
    list_p = []
    j = 0
    while j <= i:
        list_p.append(model_Y(x, P[j], N, B))
        j += 1
    p_final = P[np.argmin(list_p)]
    
    #STEP5
    if sup_gp(x, p_final, N) < 0:
        #print("Iteration in finding P is %s" %i)
        return p_final
    else:
        print("!!! FAILED TO FIND DESCENT DIRECTION!!!")

# %%
def check1(x, alpha, p, N_trial, N_tilda):
    sum1 = hinge_loss(x+alpha*p, N_trial)
    sum2 = hinge_loss(x, N_tilda)
    sum3 = -gama*alpha*(LA.norm(p,2)**2)
    return (sum1-sum2)<=sum3

# %%
def check2(N_trial, N_tilda, alpha, p):
    sum1 = aimh(N_trial)
    sum2 = aimh(N_tilda)
    sum3 = gama_k*alpha*alpha*(LA.norm(p,2)**2)
    return sum1<=(sum2+sum3)

# %%
def check3(x, alpha, p, N_trial, theta, N_start, N_tilda):
    sum1 = merit_function(x+alpha*p, N_trial, theta)
    sum2 = merit_function(x, N_start, theta)
    sum3 = (1-r)*(aimh(N_tilda)-aimh(N_start))/2
    return (sum1-sum2)<=sum3

# %%
def BFGS(B, g_new, g_old, x_new, x_old):
    I = np.identity(g_new.size)
    y = g_new-g_old
    s = x_new-x_old
    sT = np.reshape(s,(1,-1)) # Dimension: 1xN
    s = np.reshape(s,(-1,1)) # Dimension: Nx1
    yT = np.reshape(y,(1,-1))
    y = np.reshape(y,(-1,1))
    ro = 1/(yT@s)
    sum1 = I-ro*(s@yT)
    sum2 = I-ro*(y@sT)
    sum3 = ro*(s@sT)
    return (np.matmul(np.matmul(sum1,B),sum2)+sum3)

# %%
def theta_k(theta):
    return N_max*theta/(1-theta)

# %%
def p_N_trial(N_start, N_tilda, theta, theta_k, alpha, p ,x):
    sum1 = N_start + ((1-r)/2)*(N_tilda-N_start)/(1-theta)
    sum2 = theta_k*(gama*alpha*(LA.norm(p,2)**2) - hinge_loss(x, N_tilda) + hinge_loss(x, N_start))
    return round(math.floor(sum1-sum2))
    #return sum1, sum2

# %%
def first_N_trial(N_start, N_tilda, theta, theta_k, alpha, x):
    sum1 = N_start+(1-r)/2*(N_tilda-N_start)/(1-theta)
    sum2 = theta_k*(gama*alpha-hinge_loss(x, N_tilda)+hinge_loss(x, N_start))
    return math.ceil(sum1-sum2)

# %%
def candidates(N_trial, N_tilda):
    storage = []
    storage.append(int(N_trial))
    storage.append(int(math.ceil((N_trial+N_tilda)/2)))
    storage.append(N_tilda)
    return storage

# %%
def scores(k, x):
    true_pos = 0
    true_neg = 0
    false_pos = 0
    false_neg = 0
    correct = 0
    for i in range(test.shape[0]):
        value = np.matmul(test.iloc[i,:], x)
        if value > 0 and labels_test[i] > 0:
            true_pos += 1
        if value < 0 and labels_test[i] < 0:
            true_neg += + 1
        if value < 0 and labels_test[i] > 0:
            false_pos += + 1
        if value > 0 and labels_test[i] < 0:
            false_neg += + 1
        if value*labels_test[i]>0:
            correct += 1      
    F1 = round(true_pos/(true_pos + (false_pos+false_neg)/2),3)    
    Accuracy = round(correct / test.shape[0], 3)
    print("Iteration: %s | Accuracy: %s | F1: %s" %(k, F1, Accuracy))
    return F1, Accuracy

# %%
def backtracking_IRNS(B, x, N_trial, N_tilda, N_start, theta):
    alpha_start = 0.5
    degree = 0
    g0 = hl_der(x, N_trial[0])
    g1 = hl_der(x, N_trial[1])
    g2 = hl_der(x, N_trial[2])
    
    p0 = descentDirection(g0, e, i_max, B, x, N_trial[0])
    #print("P0 done")
    p1 = descentDirection(g1, e, i_max, B, x, N_trial[1])
    #print("P1 done")
    p2 = descentDirection(g2, e, i_max, B, x, N_trial[2])
    #print("P2 done")
    
    while True:
        alpha = alpha_start**degree
        
        first = check1(x, alpha, p0, N_trial[0], N_tilda)
        second = check2(N_trial[0], N_tilda, alpha, p0)
        third = check3(x, alpha, p0, N_trial[0], theta, N_start, N_tilda)
        if first and second and third:
            print("Alpha: %s | Trial value: %s" %(alpha,0))
            return alpha, p0, N_trial[0]
            break
        else:
            first = check1(x, alpha, p1, N_trial[1], N_tilda)
            second = check2(N_trial[1], N_tilda, alpha, p1) 
            third = check3(x, alpha, p1, N_trial[1], theta, N_start, N_tilda)
            if first and second and third:
                print("Alpha: %s | Trial value: %s" %(alpha,1))
                return alpha, p1, N_trial[1]
                break
            else:
                first = check1(x, alpha, p2, N_trial[2], N_tilda)
                second = check2(N_trial[2], N_tilda, alpha, p2) 
                third = check3(x, alpha, p2, N_trial[2], theta, N_start, N_tilda)
                if first and second and third:
                    print("Alpha: %s | Trial value: %s" %(alpha,2))
                    return alpha, p2, N_trial[2]
                    break
                else:
                    if degree >= 10:
                        print("forced to stop")
                        return alpha, p2, N_trial[2]
                        break
                    degree += 1
                    print(degree)

# %%
def backtracking_normal(B, x, N_trial, N_tilda, N_start, theta):
    alpha_start = 0.5
    degree = 0
    g = hl_der(x, N_trial)
    p = descentDirection(g,e,i_max,B,x,N_trial)
    while True:
        alpha = alpha_start**degree
        
        first = check1(x, alpha, p, N_trial, N_tilda)
        third = check3(x, alpha, p, N_trial, theta, N_start, N_tilda)
        #print(first, third)
        if first and third:
            #print("Alpha: %s" %alpha)
            return alpha, p
            break
        else:
            if degree >= 10:
                #print("forced to stop")
                return alpha, p
                break
            degree += 1
            #print(degree)

# %%
N_max = train.shape[0]
B0 = np.identity(x0.size)
gama = math.pow(10,-4)
e = math.pow(10,-4)
m = math.pow(10,-4)
theta0 = 0.9
i_max = 100
gama_k = 1
r = 0.95
l = math.pow(10,-5)

# %%
def algorithm(method): 
    start = time()
    
    max_fev = 0
    MAX_FEV = []
    MAX_FEV.append(max_fev)
    
    f_Ntrain = []
    N_tilda = []
    trial_N = []
    ITER = []
    ACC = []
    F1 = []
    T = []
    X = []
    P = []
    B = []
    G = []
    C = []
    A = []
    N = []
    
    X.append(x0)
    if method == "IRNS":
        N0 = math.ceil(0.1*N_max)
        N.append(N0)
        g0 = hl_der(x0, N[0])
        G.append(g0)
        max_fev += N[0]
        MAX_FEV.append(max_fev)
        f_Ntrain.append(hinge_loss(X[0],N_max))
         
    if method == "HEUR":
        N0 = math.ceil(0.1*N_max)
        N.append(N0)
        g0 = hl_der(x0, N[0])
        G.append(g0)
        max_fev += N[0]
        MAX_FEV.append(max_fev)
        f_Ntrain.append(hinge_loss(X[0],N_max))
        
    if method == "FSS":
        N0 = train.shape[0]
        N.append(N0)
        g0 = hl_der(X[0], N[0])
        G.append(g0)
        max_fev += N[0]
        MAX_FEV.append(max_fev)
        f_Ntrain.append(hinge_loss(X[0],N_max))
        
    N_tilda.append(0)
    T.append(theta0)
    B.append(B0)

    
    k = 0
    ITER.append(0)
    #while max_fev <= 10**5:
    while k <= 100:
        if method == "IRNS":
            N_tilda.append(new_sample(N[k]))
            T.append(find_theta(X[k], N_tilda[k+1], N[k], T[k]))
            
            #N_trial = round(0.8*N_tilda[-1])
            if k == 0:
                N_trial = first_N_trial(N[0], N_tilda[1], T[1], theta_k(T[1]), 1, X[0])
            else:
                N_trial = p_N_trial(N[k], N_tilda[k+1], T[k+1], theta_k(T[k+1]), A[-1], P[k-1] ,X[k])
            
            trial_N.append(N_trial)
            three_canditates = candidates(N_trial, N_tilda[k+1])
            C.append(three_canditates)
            print(C[k])
            alpha, p, N_new = backtracking_IRNS(B[k],X[k],three_canditates,N_tilda[k+1],N[k],T[k+1])
            N.append(N_new)
            max_fev += N[-1]
            MAX_FEV.append(max_fev)
            
        if method == "HEUR":
            N_tilda.append(new_sample(N[k]))
            T.append(find_theta(X[k], N_tilda[k+1], N[k], T[k]))
            N_trial = round(min(1.1*N[k],N_max))
            N.append(N_trial)
            alpha, p = backtracking_normal(B[k],X[k],N_trial,N_tilda[k+1],N[k],T[k+1])
            max_fev += N[-1]
            MAX_FEV.append(max_fev)
            
        if method == "FSS":
            N_tilda.append(train.shape[0])
            T.append(find_theta(X[k], N_tilda[k+1], N[k], T[k]))
            N_trial = train.shape[0]
            alpha, p = backtracking_normal(B[k], X[k], N_trial, N_tilda[k+1], N[k], T[k+1])
            N.append(train.shape[0])
            max_fev += N[-1]
            MAX_FEV.append(max_fev)

        P.append(p)
        A.append(alpha)

        #Step 4
        sk = alpha*P[k]
        X.append(X[k]+sk)
        f_Ntrain.append(hinge_loss(X[-1],N_max))
    

        F, Accuracy = scores(k, X[-1])
        F1.append(F)
        ACC.append(Accuracy)

        #print("Descent: %s | Semiposdef: %s " %(np.matmul(G[-1],P[-1])<0,np.all(np.linalg.eigvals(B[-1]) > 0)))

        #Step 5
        G.append(hl_der(X[k+1], N[k+1]))
        yk = G[k+1]-G[k]
        if np.matmul(sk,yk) >= m*LA.norm(yk,2)**2:
            B.append(BFGS(B[k], G[k+1], G[k], X[k+1], X[k]))
        else:
            B.append(B[k])

        #Step 6
        k += 1 
        ITER.append(k)
        print("-------------------------------------")
    end = time()
    b = end - start
    print(' ')
    print('Time elapsed: %s minutes and %s seconds.'%(np.floor(b / 60), np.round(b % 60)))
    return F1, ACC, MAX_FEV, f_Ntrain, N, ITER

# %%
F1_IRNS, ACC_IRNS, MAX_FEV_IRNS, f_Ntrain_IRNS, N_IRNS, ITER_IRNS = algorithm("IRNS")
# Out:
# [3773, 3776, 3778]
# Alpha: 1.0 | Trial value: 0
# Iteration: 0 | Accuracy: 0.394 | F1: 0.246
# -------------------------------------
# [4770, 4829, 4887]
# Alpha: 1.0 | Trial value: 0
# Iteration: 1 | Accuracy: 0.201 | F1: 0.75
# -------------------------------------
# [5191, 5513, 5834]
# Alpha: 1.0 | Trial value: 0
# Iteration: 2 | Accuracy: 0.377 | F1: 0.758
# -------------------------------------
# [5407, 5821, 6234]
# Alpha: 1.0 | Trial value: 0
# Iteration: 3 | Accuracy: 0.531 | F1: 0.774
# -------------------------------------
# [5640, 6040, 6440]
# Alpha: 1.0 | Trial value: 0
# Iteration: 4 | Accuracy: 0.568 | F1: 0.795
# -------------------------------------
# [5859, 6260, 6661]
# Alpha: 1.0 | Trial value: 0
# Iteration: 5 | Accuracy: 0.593 | F1: 0.813
# -------------------------------------
# [5838, 6354, 6869]
# Alpha: 1.0 | Trial value: 0
# Iteration: 6 | Accuracy: 0.607 | F1: 0.821
# -------------------------------------
# [5754, 6302, 6849]
# Alpha: 1.0 | Trial value: 0
# Iteration: 7 | Accuracy: 0.629 | F1: 0.83
# -------------------------------------
# [5617, 6193, 6769]
# Alpha: 1.0 | Trial value: 0
# Iteration: 8 | Accuracy: 0.633 | F1: 0.832
# -------------------------------------
# [5609, 6124, 6639]
# Alpha: 1.0 | Trial value: 0
# Iteration: 9 | Accuracy: 0.637 | F1: 0.836
# -------------------------------------
# [5553, 6092, 6631]
# Alpha: 1.0 | Trial value: 0
# Iteration: 10 | Accuracy: 0.642 | F1: 0.84
# -------------------------------------
# [5525, 6052, 6578]
# Alpha: 1.0 | Trial value: 0
# Iteration: 11 | Accuracy: 0.644 | F1: 0.841
# -------------------------------------
# [5461, 6007, 6552]
# Alpha: 1.0 | Trial value: 2
# Iteration: 12 | Accuracy: 0.648 | F1: 0.84
# -------------------------------------
# [6831, 7179, 7527]
# Alpha: 1.0 | Trial value: 1
# Iteration: 13 | Accuracy: 0.65 | F1: 0.841
# -------------------------------------
# [7253, 7688, 8123]
# Alpha: 1.0 | Trial value: 0
# Iteration: 14 | Accuracy: 0.655 | F1: 0.843
# -------------------------------------
# [7246, 7720, 8193]
# Alpha: 1.0 | Trial value: 2
# Iteration: 15 | Accuracy: 0.657 | F1: 0.844
# -------------------------------------
# [8391, 8739, 9086]
# Alpha: 1.0 | Trial value: 0
# Iteration: 16 | Accuracy: 0.664 | F1: 0.845
# -------------------------------------
# [8605, 8940, 9274]
# Alpha: 1.0 | Trial value: 1
# Iteration: 17 | Accuracy: 0.664 | F1: 0.845
# -------------------------------------
# [8961, 9379, 9796]
# Alpha: 1.0 | Trial value: 2
# Iteration: 18 | Accuracy: 0.663 | F1: 0.846
# -------------------------------------
# [10014, 10312, 10609]
# Alpha: 1.0 | Trial value: 1
# Iteration: 19 | Accuracy: 0.664 | F1: 0.847
# -------------------------------------
# [10599, 10849, 11099]
# Alpha: 1.0 | Trial value: 0
# Iteration: 20 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# [10948, 11160, 11372]
# Alpha: 1.0 | Trial value: 0
# Iteration: 21 | Accuracy: 0.654 | F1: 0.847
# -------------------------------------
# [11155, 11430, 11704]
# Alpha: 1.0 | Trial value: 2
# Iteration: 22 | Accuracy: 0.657 | F1: 0.846
# -------------------------------------
# [11757, 12090, 12422]
# Alpha: 1.0 | Trial value: 2
# Iteration: 23 | Accuracy: 0.657 | F1: 0.846
# -------------------------------------
# [12518, 12811, 13104]
# Alpha: 1.0 | Trial value: 2
# Iteration: 24 | Accuracy: 0.658 | F1: 0.847
# -------------------------------------
# [13114, 13433, 13752]
# Alpha: 1.0 | Trial value: 2
# Iteration: 25 | Accuracy: 0.65 | F1: 0.846
# -------------------------------------
# [13783, 14075, 14367]
# Alpha: 1.0 | Trial value: 2
# Iteration: 26 | Accuracy: 0.65 | F1: 0.846
# -------------------------------------
# [14431, 14692, 14952]
# Alpha: 1.0 | Trial value: 2
# Iteration: 27 | Accuracy: 0.652 | F1: 0.846
# -------------------------------------
# [14942, 15225, 15507]
# Alpha: 1.0 | Trial value: 2
# Iteration: 28 | Accuracy: 0.66 | F1: 0.849
# -------------------------------------
# [15572, 15804, 16035]
# Alpha: 1.0 | Trial value: 2
# Iteration: 29 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# [16170, 16353, 16536]
# Alpha: 1.0 | Trial value: 0
# Iteration: 30 | Accuracy: 0.655 | F1: 0.847
# -------------------------------------
# [16281, 16473, 16664]
# Alpha: 1.0 | Trial value: 0
# Iteration: 31 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# [16397, 16584, 16770]
# Alpha: 1.0 | Trial value: 2
# Iteration: 32 | Accuracy: 0.659 | F1: 0.848
# -------------------------------------
# [16751, 16993, 17234]
# Alpha: 1.0 | Trial value: 2
# Iteration: 33 | Accuracy: 0.656 | F1: 0.847
# -------------------------------------
# [17234, 17455, 17675]
# Alpha: 1.0 | Trial value: 2
# Iteration: 34 | Accuracy: 0.653 | F1: 0.846
# -------------------------------------
# [17656, 17875, 18094]
# Alpha: 1.0 | Trial value: 2
# Iteration: 35 | Accuracy: 0.647 | F1: 0.844
# -------------------------------------
# [18161, 18327, 18492]
# Alpha: 1.0 | Trial value: 2
# Iteration: 36 | Accuracy: 0.65 | F1: 0.845
# -------------------------------------
# [18526, 18698, 18870]
# Alpha: 1.0 | Trial value: 2
# Iteration: 37 | Accuracy: 0.648 | F1: 0.844
# -------------------------------------
# [18868, 19049, 19229]
# Alpha: 1.0 | Trial value: 2
# Iteration: 38 | Accuracy: 0.65 | F1: 0.844
# -------------------------------------
# [19236, 19403, 19570]
# 1
# Alpha: 0.5 | Trial value: 2
# Iteration: 39 | Accuracy: 0.652 | F1: 0.845
# -------------------------------------
# [19529, 19712, 19894]
# Alpha: 1.0 | Trial value: 2
# Iteration: 40 | Accuracy: 0.652 | F1: 0.845
# -------------------------------------
# [19951, 20077, 20202]
# Alpha: 1.0 | Trial value: 2
# Iteration: 41 | Accuracy: 0.651 | F1: 0.846
# -------------------------------------
# [20220, 20358, 20495]
# Alpha: 1.0 | Trial value: 2
# Iteration: 42 | Accuracy: 0.653 | F1: 0.846
# -------------------------------------
# [20490, 20632, 20773]
# Alpha: 1.0 | Trial value: 2
# Iteration: 43 | Accuracy: 0.659 | F1: 0.847
# -------------------------------------
# [20807, 20922, 21037]
# Alpha: 1.0 | Trial value: 2
# Iteration: 44 | Accuracy: 0.659 | F1: 0.847
# -------------------------------------
# [21071, 21180, 21288]
# Alpha: 1.0 | Trial value: 2
# Iteration: 45 | Accuracy: 0.656 | F1: 0.847
# -------------------------------------
# [21318, 21423, 21527]
# Alpha: 1.0 | Trial value: 2
# Iteration: 46 | Accuracy: 0.657 | F1: 0.847
# -------------------------------------
# [21533, 21644, 21754]
# Alpha: 1.0 | Trial value: 2
# Iteration: 47 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# [21738, 21854, 21969]
# Alpha: 1.0 | Trial value: 2
# Iteration: 48 | Accuracy: 0.66 | F1: 0.847
# -------------------------------------
# [21987, 22080, 22173]
# Alpha: 1.0 | Trial value: 0
# Iteration: 49 | Accuracy: 0.658 | F1: 0.847
# -------------------------------------
# [22017, 22104, 22191]
# Alpha: 1.0 | Trial value: 2
# Iteration: 50 | Accuracy: 0.659 | F1: 0.847
# -------------------------------------
# [22180, 22282, 22384]
# Alpha: 1.0 | Trial value: 2
# Iteration: 51 | Accuracy: 0.657 | F1: 0.847
# -------------------------------------
# [22430, 22499, 22568]
# Alpha: 1.0 | Trial value: 1
# Iteration: 52 | Accuracy: 0.659 | F1: 0.848
# -------------------------------------
# [22540, 22609, 22677]
# Alpha: 1.0 | Trial value: 0
# Iteration: 53 | Accuracy: 0.66 | F1: 0.847
# -------------------------------------
# [22571, 22644, 22716]
# Alpha: 1.0 | Trial value: 2
# Iteration: 54 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# [22750, 22817, 22883]
# Alpha: 1.0 | Trial value: 2
# Iteration: 55 | Accuracy: 0.659 | F1: 0.848
# -------------------------------------
# [22886, 22964, 23042]
# Alpha: 1.0 | Trial value: 2
# Iteration: 56 | Accuracy: 0.659 | F1: 0.848
# -------------------------------------
# [23025, 23109, 23193]
# Alpha: 1.0 | Trial value: 2
# Iteration: 57 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# [23198, 23267, 23336]
# Alpha: 1.0 | Trial value: 2
# Iteration: 58 | Accuracy: 0.661 | F1: 0.848
# -------------------------------------
# [23343, 23408, 23472]
# Alpha: 1.0 | Trial value: 2
# Iteration: 59 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# [23487, 23544, 23601]
# Alpha: 1.0 | Trial value: 1
# Iteration: 60 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# [23555, 23613, 23670]
# Alpha: 1.0 | Trial value: 2
# Iteration: 61 | Accuracy: 0.66 | F1: 0.849
# -------------------------------------
# [23675, 23732, 23789]
# Alpha: 1.0 | Trial value: 2
# Iteration: 62 | Accuracy: 0.66 | F1: 0.849
# -------------------------------------
# [23802, 23852, 23902]
# Alpha: 1.0 | Trial value: 0
# Iteration: 63 | Accuracy: 0.66 | F1: 0.849
# -------------------------------------
# [23830, 23873, 23915]
# Alpha: 1.0 | Trial value: 2
# Iteration: 64 | Accuracy: 0.66 | F1: 0.849
# -------------------------------------
# [23948, 23985, 24022]
# Alpha: 1.0 | Trial value: 0
# Iteration: 65 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# [23988, 24021, 24054]
# Alpha: 1.0 | Trial value: 1
# Iteration: 66 | Accuracy: 0.662 | F1: 0.85
# -------------------------------------
# [24039, 24081, 24123]
# Alpha: 1.0 | Trial value: 2
# Iteration: 67 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# [24129, 24175, 24220]
# Alpha: 1.0 | Trial value: 2
# Iteration: 68 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# [24229, 24271, 24312]
# Alpha: 1.0 | Trial value: 1
# Iteration: 69 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# [24282, 24321, 24360]
# Alpha: 1.0 | Trial value: 2
# Iteration: 70 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# [24379, 24412, 24445]
# Alpha: 1.0 | Trial value: 0
# Iteration: 71 | Accuracy: 0.66 | F1: 0.849
# -------------------------------------
# [24381, 24422, 24463]
# Alpha: 1.0 | Trial value: 2
# Iteration: 72 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# [24455, 24499, 24543]
# Alpha: 1.0 | Trial value: 2
# Iteration: 73 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# [24553, 24586, 24619]
# Alpha: 1.0 | Trial value: 0
# Iteration: 74 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# [24555, 24592, 24628]
# Alpha: 1.0 | Trial value: 1
# Iteration: 75 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# [24590, 24628, 24665]
# Alpha: 1.0 | Trial value: 0
# Iteration: 76 | Accuracy: 0.66 | F1: 0.849
# -------------------------------------
# [24598, 24631, 24663]
# Alpha: 1.0 | Trial value: 0
# Iteration: 77 | Accuracy: 0.659 | F1: 0.848
# -------------------------------------
# [24607, 24639, 24671]
# Alpha: 1.0 | Trial value: 2
# Iteration: 78 | Accuracy: 0.66 | F1: 0.849
# -------------------------------------
# [24666, 24703, 24740]
# Alpha: 1.0 | Trial value: 2
# Iteration: 79 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# [24729, 24768, 24806]
# Alpha: 1.0 | Trial value: 2
# Iteration: 80 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# [24799, 24834, 24869]
# Alpha: 1.0 | Trial value: 2
# Iteration: 81 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# [24868, 24898, 24928]
# 1
# Alpha: 0.5 | Trial value: 2
# Iteration: 82 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# [24920, 24953, 24985]
# Alpha: 1.0 | Trial value: 2
# Iteration: 83 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# [24981, 25010, 25039]
# Alpha: 1.0 | Trial value: 1
# Iteration: 84 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# [25022, 25042, 25062]
# Alpha: 1.0 | Trial value: 2
# Iteration: 85 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# [25067, 25090, 25112]
# Alpha: 1.0 | Trial value: 2
# Iteration: 86 | Accuracy: 0.662 | F1: 0.85
# -------------------------------------
# [25141, 25150, 25159]
# Alpha: 1.0 | Trial value: 2
# Iteration: 87 | Accuracy: 0.662 | F1: 0.85
# -------------------------------------
# [25160, 25182, 25204]
# Alpha: 1.0 | Trial value: 2
# Iteration: 88 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# [25199, 25223, 25247]
# Alpha: 1.0 | Trial value: 2
# Iteration: 89 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# [25257, 25273, 25288]
# Alpha: 1.0 | Trial value: 0
# Iteration: 90 | Accuracy: 0.661 | F1: 0.85
# -------------------------------------
# [25266, 25282, 25297]
# Alpha: 1.0 | Trial value: 1
# Iteration: 91 | Accuracy: 0.662 | F1: 0.85
# -------------------------------------
# [25299, 25310, 25321]
# Alpha: 1.0 | Trial value: 0
# Iteration: 92 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# [25325, 25331, 25337]
# Alpha: 1.0 | Trial value: 0
# Iteration: 93 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# [25326, 25344, 25362]
# Alpha: 1.0 | Trial value: 0
# Iteration: 94 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# [25326, 25345, 25363]
# Alpha: 1.0 | Trial value: 1
# Iteration: 95 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# [25342, 25362, 25381]
# Alpha: 1.0 | Trial value: 2
# Iteration: 96 | Accuracy: 0.66 | F1: 0.849
# -------------------------------------
# [25382, 25399, 25415]
# Alpha: 1.0 | Trial value: 2
# Iteration: 97 | Accuracy: 0.659 | F1: 0.848
# -------------------------------------
# [25437, 25442, 25447]
# Alpha: 1.0 | Trial value: 0
# Iteration: 98 | Accuracy: 0.66 | F1: 0.849
# -------------------------------------
# [25446, 25457, 25468]
# Alpha: 1.0 | Trial value: 0
# Iteration: 99 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# [25455, 25466, 25477]
# Alpha: 1.0 | Trial value: 0
# Iteration: 100 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
#
# Time elapsed: 117.0 minutes and 7.0 seconds.

# %%
F1_HEUR, ACC_HEUR, MAX_FEV_HEUR, f_Ntrain_HEUR, N_HEUR, ITER_HEUR = algorithm("HEUR")
# Out:
# Iteration: 0 | Accuracy: 0.394 | F1: 0.246
# -------------------------------------
# Iteration: 1 | Accuracy: 0.203 | F1: 0.749
# -------------------------------------
# Iteration: 2 | Accuracy: 0.386 | F1: 0.758
# -------------------------------------
# Iteration: 3 | Accuracy: 0.544 | F1: 0.77
# -------------------------------------
# Iteration: 4 | Accuracy: 0.56 | F1: 0.793
# -------------------------------------
# Iteration: 5 | Accuracy: 0.58 | F1: 0.81
# -------------------------------------
# Iteration: 6 | Accuracy: 0.606 | F1: 0.82
# -------------------------------------
# Iteration: 7 | Accuracy: 0.634 | F1: 0.831
# -------------------------------------
# Iteration: 8 | Accuracy: 0.634 | F1: 0.833
# -------------------------------------
# Iteration: 9 | Accuracy: 0.638 | F1: 0.837
# -------------------------------------
# Iteration: 10 | Accuracy: 0.644 | F1: 0.841
# -------------------------------------
# Iteration: 11 | Accuracy: 0.647 | F1: 0.841
# -------------------------------------
# Iteration: 12 | Accuracy: 0.648 | F1: 0.841
# -------------------------------------
# Iteration: 13 | Accuracy: 0.658 | F1: 0.842
# -------------------------------------
# Iteration: 14 | Accuracy: 0.654 | F1: 0.842
# -------------------------------------
# Iteration: 15 | Accuracy: 0.656 | F1: 0.845
# -------------------------------------
# Iteration: 16 | Accuracy: 0.662 | F1: 0.846
# -------------------------------------
# Iteration: 17 | Accuracy: 0.665 | F1: 0.846
# -------------------------------------
# Iteration: 18 | Accuracy: 0.661 | F1: 0.845
# -------------------------------------
# Iteration: 19 | Accuracy: 0.659 | F1: 0.846
# -------------------------------------
# Iteration: 20 | Accuracy: 0.659 | F1: 0.846
# -------------------------------------
# Iteration: 21 | Accuracy: 0.655 | F1: 0.847
# -------------------------------------
# Iteration: 22 | Accuracy: 0.658 | F1: 0.848
# -------------------------------------
# Iteration: 23 | Accuracy: 0.658 | F1: 0.848
# -------------------------------------
# Iteration: 24 | Accuracy: 0.66 | F1: 0.847
# -------------------------------------
# Iteration: 25 | Accuracy: 0.662 | F1: 0.848
# -------------------------------------
# Iteration: 26 | Accuracy: 0.665 | F1: 0.849
# -------------------------------------
# Iteration: 27 | Accuracy: 0.662 | F1: 0.848
# -------------------------------------
# Iteration: 28 | Accuracy: 0.656 | F1: 0.847
# -------------------------------------
# Iteration: 29 | Accuracy: 0.651 | F1: 0.846
# -------------------------------------
# Iteration: 30 | Accuracy: 0.651 | F1: 0.847
# -------------------------------------
# Iteration: 31 | Accuracy: 0.65 | F1: 0.845
# -------------------------------------
# Iteration: 32 | Accuracy: 0.655 | F1: 0.846
# -------------------------------------
# Iteration: 33 | Accuracy: 0.657 | F1: 0.846
# -------------------------------------
# Iteration: 34 | Accuracy: 0.658 | F1: 0.847
# -------------------------------------
# Iteration: 35 | Accuracy: 0.657 | F1: 0.846
# -------------------------------------
# Iteration: 36 | Accuracy: 0.657 | F1: 0.847
# -------------------------------------
# Iteration: 37 | Accuracy: 0.654 | F1: 0.846
# -------------------------------------
# Iteration: 38 | Accuracy: 0.655 | F1: 0.847
# -------------------------------------
# Iteration: 39 | Accuracy: 0.652 | F1: 0.846
# -------------------------------------
# Iteration: 40 | Accuracy: 0.649 | F1: 0.846
# -------------------------------------
# Iteration: 41 | Accuracy: 0.653 | F1: 0.846
# -------------------------------------
# Iteration: 42 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# Iteration: 43 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 44 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 45 | Accuracy: 0.665 | F1: 0.85
# -------------------------------------
# Iteration: 46 | Accuracy: 0.664 | F1: 0.849
# -------------------------------------
# Iteration: 47 | Accuracy: 0.666 | F1: 0.85
# -------------------------------------
# Iteration: 48 | Accuracy: 0.665 | F1: 0.85
# -------------------------------------
# Iteration: 49 | Accuracy: 0.664 | F1: 0.85
# -------------------------------------
# Iteration: 50 | Accuracy: 0.666 | F1: 0.85
# -------------------------------------
# Iteration: 51 | Accuracy: 0.664 | F1: 0.85
# -------------------------------------
# Iteration: 52 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# Iteration: 53 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# Iteration: 54 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 55 | Accuracy: 0.664 | F1: 0.85
# -------------------------------------
# Iteration: 56 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# Iteration: 57 | Accuracy: 0.665 | F1: 0.85
# -------------------------------------
# Iteration: 58 | Accuracy: 0.665 | F1: 0.85
# -------------------------------------
# Iteration: 59 | Accuracy: 0.665 | F1: 0.85
# -------------------------------------
# Iteration: 60 | Accuracy: 0.665 | F1: 0.85
# -------------------------------------
# Iteration: 61 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# Iteration: 62 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# Iteration: 63 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 64 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 65 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# Iteration: 66 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 67 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# Iteration: 68 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 69 | Accuracy: 0.66 | F1: 0.849
# -------------------------------------
# Iteration: 70 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 71 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 72 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 73 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# Iteration: 74 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# Iteration: 75 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 76 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 77 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 78 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 79 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 80 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 81 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 82 | Accuracy: 0.661 | F1: 0.848
# -------------------------------------
# Iteration: 83 | Accuracy: 0.661 | F1: 0.848
# -------------------------------------
# Iteration: 84 | Accuracy: 0.661 | F1: 0.848
# -------------------------------------
# Iteration: 85 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 86 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# Iteration: 87 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# Iteration: 88 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# Iteration: 89 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# Iteration: 90 | Accuracy: 0.664 | F1: 0.85
# -------------------------------------
# Iteration: 91 | Accuracy: 0.664 | F1: 0.85
# -------------------------------------
# Iteration: 92 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# Iteration: 93 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 94 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 95 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 96 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 97 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 98 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 99 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# Iteration: 100 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
#
# Time elapsed: 45.0 minutes and 57.0 seconds.

# %%
F1_FSS, ACC_FSS, MAX_FEV_FSS, f_Ntrain_FSS, N_FSS, ITER_FSS = algorithm("FSS")
# Out:
# Iteration: 0 | Accuracy: 0.394 | F1: 0.246
# -------------------------------------
# Iteration: 1 | Accuracy: 0.052 | F1: 0.754
# -------------------------------------
# Iteration: 2 | Accuracy: 0.233 | F1: 0.758
# -------------------------------------
# Iteration: 3 | Accuracy: 0.524 | F1: 0.753
# -------------------------------------
# Iteration: 4 | Accuracy: 0.46 | F1: 0.779
# -------------------------------------
# Iteration: 5 | Accuracy: 0.499 | F1: 0.792
# -------------------------------------
# Iteration: 6 | Accuracy: 0.603 | F1: 0.817
# -------------------------------------
# Iteration: 7 | Accuracy: 0.629 | F1: 0.826
# -------------------------------------
# Iteration: 8 | Accuracy: 0.64 | F1: 0.831
# -------------------------------------
# Iteration: 9 | Accuracy: 0.638 | F1: 0.834
# -------------------------------------
# Iteration: 10 | Accuracy: 0.64 | F1: 0.836
# -------------------------------------
# Iteration: 11 | Accuracy: 0.646 | F1: 0.841
# -------------------------------------
# Iteration: 12 | Accuracy: 0.648 | F1: 0.841
# -------------------------------------
# Iteration: 13 | Accuracy: 0.647 | F1: 0.841
# -------------------------------------
# Iteration: 14 | Accuracy: 0.648 | F1: 0.84
# -------------------------------------
# Iteration: 15 | Accuracy: 0.652 | F1: 0.841
# -------------------------------------
# Iteration: 16 | Accuracy: 0.668 | F1: 0.846
# -------------------------------------
# Iteration: 17 | Accuracy: 0.669 | F1: 0.846
# -------------------------------------
# Iteration: 18 | Accuracy: 0.664 | F1: 0.846
# -------------------------------------
# Iteration: 19 | Accuracy: 0.664 | F1: 0.846
# -------------------------------------
# Iteration: 20 | Accuracy: 0.655 | F1: 0.845
# -------------------------------------
# Iteration: 21 | Accuracy: 0.657 | F1: 0.847
# -------------------------------------
# Iteration: 22 | Accuracy: 0.652 | F1: 0.846
# -------------------------------------
# Iteration: 23 | Accuracy: 0.652 | F1: 0.846
# -------------------------------------
# Iteration: 24 | Accuracy: 0.653 | F1: 0.846
# -------------------------------------
# Iteration: 25 | Accuracy: 0.66 | F1: 0.847
# -------------------------------------
# Iteration: 26 | Accuracy: 0.664 | F1: 0.849
# -------------------------------------
# Iteration: 27 | Accuracy: 0.661 | F1: 0.848
# -------------------------------------
# Iteration: 28 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# Iteration: 29 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# Iteration: 30 | Accuracy: 0.655 | F1: 0.847
# -------------------------------------
# Iteration: 31 | Accuracy: 0.654 | F1: 0.846
# -------------------------------------
# Iteration: 32 | Accuracy: 0.658 | F1: 0.848
# -------------------------------------
# Iteration: 33 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# Iteration: 34 | Accuracy: 0.661 | F1: 0.848
# -------------------------------------
# Iteration: 35 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# Iteration: 36 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# Iteration: 37 | Accuracy: 0.659 | F1: 0.848
# -------------------------------------
# Iteration: 38 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# Iteration: 39 | Accuracy: 0.658 | F1: 0.848
# -------------------------------------
# Iteration: 40 | Accuracy: 0.659 | F1: 0.848
# -------------------------------------
# Iteration: 41 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# Iteration: 42 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# Iteration: 43 | Accuracy: 0.661 | F1: 0.848
# -------------------------------------
# Iteration: 44 | Accuracy: 0.659 | F1: 0.847
# -------------------------------------
# Iteration: 45 | Accuracy: 0.661 | F1: 0.848
# -------------------------------------
# Iteration: 46 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 47 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 48 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# Iteration: 49 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# Iteration: 50 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 51 | Accuracy: 0.664 | F1: 0.85
# -------------------------------------
# Iteration: 52 | Accuracy: 0.665 | F1: 0.85
# -------------------------------------
# Iteration: 53 | Accuracy: 0.667 | F1: 0.851
# -------------------------------------
# Iteration: 54 | Accuracy: 0.666 | F1: 0.851
# -------------------------------------
# Iteration: 55 | Accuracy: 0.664 | F1: 0.85
# -------------------------------------
# Iteration: 56 | Accuracy: 0.665 | F1: 0.85
# -------------------------------------
# Iteration: 57 | Accuracy: 0.664 | F1: 0.85
# -------------------------------------
# Iteration: 58 | Accuracy: 0.664 | F1: 0.85
# -------------------------------------
# Iteration: 59 | Accuracy: 0.664 | F1: 0.85
# -------------------------------------
# Iteration: 60 | Accuracy: 0.665 | F1: 0.85
# -------------------------------------
# Iteration: 61 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# Iteration: 62 | Accuracy: 0.664 | F1: 0.85
# -------------------------------------
# Iteration: 63 | Accuracy: 0.665 | F1: 0.85
# -------------------------------------
# Iteration: 64 | Accuracy: 0.665 | F1: 0.85
# -------------------------------------
# Iteration: 65 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 66 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# Iteration: 67 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# Iteration: 68 | Accuracy: 0.664 | F1: 0.85
# -------------------------------------
# Iteration: 69 | Accuracy: 0.664 | F1: 0.85
# -------------------------------------
# Iteration: 70 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 71 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 72 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 73 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 74 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 75 | Accuracy: 0.662 | F1: 0.85
# -------------------------------------
# Iteration: 76 | Accuracy: 0.66 | F1: 0.849
# -------------------------------------
# Iteration: 77 | Accuracy: 0.66 | F1: 0.849
# -------------------------------------
# Iteration: 78 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 79 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 80 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 81 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 82 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 83 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 84 | Accuracy: 0.661 | F1: 0.848
# -------------------------------------
# Iteration: 85 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# Iteration: 86 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 87 | Accuracy: 0.663 | F1: 0.849
# -------------------------------------
# Iteration: 88 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 89 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 90 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 91 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 92 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# Iteration: 93 | Accuracy: 0.663 | F1: 0.85
# -------------------------------------
# Iteration: 94 | Accuracy: 0.662 | F1: 0.849
# -------------------------------------
# Iteration: 95 | Accuracy: 0.661 | F1: 0.849
# -------------------------------------
# Iteration: 96 | Accuracy: 0.66 | F1: 0.848
# -------------------------------------
# Iteration: 97 | Accuracy: 0.659 | F1: 0.848
# -------------------------------------
# Iteration: 98 | Accuracy: 0.658 | F1: 0.848
# -------------------------------------
# Iteration: 99 | Accuracy: 0.659 | F1: 0.848
# -------------------------------------
# Iteration: 100 | Accuracy: 0.659 | F1: 0.848
# -------------------------------------
#
# Time elapsed: 53.0 minutes and 31.0 seconds.

# %% [markdown]
# ### Graphics

# %%
plt.figure(figsize=(10, 5))
plt.plot(ACC_IRNS)
plt.plot(ACC_HEUR)
plt.plot(ACC_FSS)
plt.legend(["IRNS", "Heuristics","Full sample size"], loc ="lower right")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.yscale("log")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(F1_IRNS)
plt.plot(F1_HEUR)
plt.plot(F1_FSS)
plt.legend(["IRNS", "Heuristics","Full sample size"], loc ="lower right")
plt.xlabel("Iteration")
plt.ylabel("F1 Score")
plt.yscale("log")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(MAX_FEV_IRNS)
plt.plot(MAX_FEV_HEUR)
plt.plot(MAX_FEV_FSS)
plt.legend(["IRNS", "Heuristics","Full sample size"], loc ="upper left")
plt.xlabel("Iteration")
plt.ylabel("FEV")
plt.yscale("log")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(f_Ntrain_IRNS)
plt.plot(f_Ntrain_HEUR)
plt.plot(f_Ntrain_FSS)
plt.legend(["IRNS", "Heuristics","Full sample size"], loc ="upper right")
plt.xlabel("Iteration")
plt.ylabel("f_Ntrain")
plt.yscale("log")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(MAX_FEV_IRNS[:-1],f_Ntrain_IRNS)
plt.plot(MAX_FEV_HEUR[:-1],f_Ntrain_HEUR)
plt.plot(MAX_FEV_FSS[:-1],f_Ntrain_FSS)
plt.legend(["IRNS", "Heuristics","Full sample size"], loc ="upper right")
plt.xlabel("Mushrooms: FEV")
plt.ylabel("f_Ntrain")
plt.yscale("log")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(N_IRNS)
plt.plot(N_HEUR)
plt.plot(N_FSS)
plt.legend(["IRNS", "Heuristics","Full sample size"], loc ="lower right")
plt.xlabel("Iteration")
plt.ylabel("Sample size")
plt.yscale("log")
plt.show()
